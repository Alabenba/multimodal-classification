# %%
import os
import re
import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
custom_color_map=[
    "#9370DB", "#EE82EE", "#6495ED", "#DB7093", "#1E90FF", "#40E0D0", "#008B8B",
    "#2E8B57", "#00FF00", "#6B8E23", "#F0E68C", "#DAA520", "#FF8C00", "#FFA07A",
    "#FF7F50", "#DC143C", "#800000", "#D2691E", "#BC8F8F", "#5F9EA0", "#9ACD32",
    "#FFA500", "#FFD700", "#B22222", "#4B0082", "FF0000"
]
default_color="#FF0000"

# %%
cwd=os.getcwd()
image_dir = os.path.join(cwd,'data/recipes_splitted/images')

df_extracted_features = pd.read_pickle(os.path.join(image_dir,"extracted_features.pkl"))
#print("Extraced features from images: \n", df_extracted_features)

# %%
features=df_extracted_features['features'].values.tolist()
labels=df_extracted_features['labels'].values.tolist()
image_names=df_extracted_features['image_names'].values.tolist()

unique_labels=list(set(labels))
number_of_colors=len(unique_labels)
possible_color_indicies=np.linspace(0,number_of_colors-1,number_of_colors,dtype=int)
labels2color_indices=dict(zip(unique_labels,possible_color_indicies))

print(labels2color_indices)

color_indicies=[]
for l in labels:
    color_index=labels2color_indices[l]
    color_indicies.append(color_index)
# Out:
# {'steak': 0, 'tiramisu': 1, 'sashimi': 3, 'sushi': 2}

# %%
#PCA

pca = PCA(n_components=2)
pca_2D_embeddings = pca.fit_transform(features)

dict_PCA_2D = {
    'pca-1' : pca_2D_embeddings[:,0],
    'pca-2' : pca_2D_embeddings[:,1],
    'labels' : labels,
    'color_indicies': color_indicies,
    'image_names': image_names
}

df_PCA_2D=pd.DataFrame(dict_PCA_2D)
#print(df_2D_PCA)

# %%
traces=[]

for n in range(0,number_of_colors):
    df_category=df_PCA_2D[(df_PCA_2D.color_indicies==n)]
    point_name=str(df_category['labels'][df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['image_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='t-SNE reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
# <div id="1fcac613-9101-4a4e-998d-8ddd726267d7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1fcac613-9101-4a4e-998d-8ddd726267d7", [{"marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "colorscale": "Viridis"}, "type": "scatter", "uid": "14176155-6e63-4bc3-9211-244a986922d4", "name": "steak", "text": ["1-1.jpg", "1-2.jpg", "1-3.jpg", "1-4.jpg", "1-5.jpg", "1-6.jpg", "10-1.jpg", "10-2.jpg", "10-3.jpg", "10-4.jpg", "10-5.jpg", "2-1.jpg", "3-1.jpg", "3-2.jpg", "3-3.jpg", "4-1.jpg", "4-2.jpg", "4-3.jpg", "4-4.jpg", "4-5.jpg", "5-1.jpg", "5-2.jpg", "5-3.jpg", "6-1.jpg", "6-2.jpg", "6-3.jpg", "6-4.jpg", "6-5.jpg", "6-6.jpg", "6-7.jpg", "7-1.jpg", "7-2.jpg", "7-3.jpg", "7-4.jpg", "7-5.jpg", "7-6.jpg", "8-1.jpg", "8-2.jpg", "8-3.jpg", "8-4.jpg", "8-5.jpg", "9-1.jpg", "9-2.jpg"], "mode": "markers", "y": [-6.763345549689128, -5.066460380419737, -6.531327807885075, -6.700310061250056, -6.224201489429151, -7.249819550326953, -7.210280755407414, -5.742902819143595, -7.419146946843272, -6.4606268771098465, -8.28601917453869, -5.737696898042693, -5.320648403661755, -5.401973713593848, -6.0932520517628515, -6.308443195012638, -7.614931662463061, -6.183942036522978, -1.0258003221402854, -6.378235050167496, -5.58638460245206, -5.797467960050017, -5.541136256748573, -7.699049372191147, -6.294614452091627, -5.122916154104556, -7.336187069224333, -7.046767303433305, -6.676241331627942, -7.238404053870246, -5.707582846358939, -8.446522451253092, -3.9203997313278234, -6.237352732392508, -6.732759732845834, -6.846435966692326, -6.676421638263166, -5.8987853561671475, -5.201668911030343, -5.290879549543575, -5.419893925207118, -4.57311859746648, -7.6850713803287425], "x": [-1.9251201379349594, 0.9416536269704304, -1.6478683498313822, -0.7139823855590048, -0.17397961755752264, -1.650732717006798, -0.24516376444948237, -0.7608770279661194, -1.9833805749982376, 0.0962686829074018, -1.7463684954016587, 0.028576553160309482, 0.3261087152128037, 2.2292702345251048, -1.2640421027001965, -1.3457863575476305, -1.1627915752258868, 2.095219896925612, 3.791133314148642, -0.42466409256617116, 0.9311526349839168, 3.5708387608876593, -0.6049882883192678, -1.3240067058135752, -0.4377210020610583, 1.8032237295427214, -0.5183097775132992, -0.8567157298488766, -0.5809567869687683, 0.4130331376621769, 1.0761691992208215, -1.0285165305042325, 1.7940180322312886, -0.8770914232976132, -1.1047378873027482, -0.28117924308839876, 0.597089582282143, 0.6261418418498377, -0.9925321416687591, -1.491730302572977, -0.7534309026425713, -1.8282214125161078, -1.3370633286827016]}, {"marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "colorscale": "Viridis"}, "type": "scatter", "uid": "011d1289-8612-4ad1-b6c2-d7fe42ddec1c", "name": "tiramisu", "text": ["1-1.jpg", "1-2.jpg", "1-3.jpg", "1-4.jpg", "10-1.jpg", "10-10.jpg", "10-2.jpg", "10-3.jpg", "10-4.jpg", "10-5.jpg", "10-6.jpg", "10-7.jpg", "10-8.jpg", "10-9.jpg", "2-1.jpg", "2-2.jpg", "2-3.jpg", "2-4.jpg", "2-5.jpg", "2-6.jpg", "2-7.jpg", "2-8.jpg", "2-9.jpg", "3-1.jpg", "3-2.jpg", "3-3.jpg", "3-4.jpg", "3-5.jpg", "3-6.jpg", "3-7.jpg", "3-8.jpg", "4-1.jpg", "4-2.jpg", "4-3.jpg", "4-4.jpg", "4-5.jpg", "4-6.jpg", "4-7.jpg", "4-8.jpg", "4-9.jpg", "5-1.jpg", "5-2.jpg", "5-3.jpg", "5-4.jpg", "6-1.jpg", "6-2.jpg", "6-3.jpg", "6-4.jpg", "7-1.jpg", "7-2.jpg", "7-3.jpg", "7-4.jpg", "7-5.jpg", "7-6.jpg", "7-7.jpg", "7-8.jpg", "8-1.jpg", "8-2.jpg", "8-3.jpg", "8-4.jpg", "8-5.jpg", "8-6.jpg", "8-7.jpg", "8-8.jpg", "9-1.jpg", "9-2.jpg", "9-3.jpg", "9-4.jpg", "9-5.jpg", "9-6.jpg", "9-7.jpg", "9-8.jpg", "9-9.jpg"], "mode": "markers", "y": [7.403889575690001, 1.9362573967259633, 3.2062343599891876, -1.7339099545006644, 10.206336155585314, -1.081701704220634, -1.255847998640628, 12.231466199409152, 10.666465476743639, 4.594291212513 ...

# %%
    #t-SNE 2D
    
    tsne2D = TSNE(perplexity=50, n_components=2, verbose=2, init='pca', n_iter=2000,
                  n_iter_without_progress=500, learning_rate=20,method='exact')
    tsne_2D_embeddings = tsne2D.fit_transform(features)
    
    dict_TSNE_2D = {
    'pca-1' : tsne_2D_embeddings[:,0],
    'pca-2' : tsne_2D_embeddings[:,1],
    'labels' : labels,
    'color_indicies': color_indicies,
    'image_names': image_names
}

df_TSNE_2D=pd.DataFrame(dict_TSNE_2D)
#print(df_2D_PCA)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 160 / 160
# [t-SNE] Mean sigma: 6.053790
# [t-SNE] Iteration 50: error = 41.9423359, gradient norm = 0.1140180 (50 iterations in 0.190s)
# [t-SNE] Iteration 100: error = 41.6887887, gradient norm = 0.0192523 (50 iterations in 0.144s)
# [t-SNE] Iteration 150: error = 41.6889352, gradient norm = 0.0267213 (50 iterations in 0.146s)
# [t-SNE] Iteration 200: error = 41.6888334, gradient norm = 0.0218289 (50 iterations in 0.171s)
# [t-SNE] Iteration 250: error = 41.6886809, gradient norm = 0.0111343 (50 iterations in 0.191s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 41.688681
# [t-SNE] Iteration 300: error = 0.1426767, gradient norm = 0.0013563 (50 iterations in 0.147s)
# [t-SNE] Iteration 350: error = 0.1372840, gradient norm = 0.0001508 (50 iterations in 0.150s)
# [t-SNE] Iteration 400: error = 0.1371525, gradient norm = 0.0000074 (50 iterations in 0.146s)
# [t-SNE] Iteration 450: error = 0.1371524, gradient norm = 0.0000003 (50 iterations in 0.157s)
# [t-SNE] Iteration 500: error = 0.1371524, gradient norm = 0.0000000 (50 iterations in 0.144s)
# [t-SNE] Iteration 500: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 500 iterations: 0.137152

# %%
traces=[]

for n in range(0,number_of_colors):
    df_category=df_TSNE_2D[(df_TSNE_2D.color_indicies==n)]
    point_name=str(df_category['labels'][df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['image_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='t-SNE reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)
# Out:
# <div id="f3e7cf21-6c08-4726-a0cf-0ca5d49570ad" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f3e7cf21-6c08-4726-a0cf-0ca5d49570ad", [{"marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "colorscale": "Viridis"}, "type": "scatter", "uid": "6cb842f9-0f6a-4d8a-a073-58a1d2646614", "name": "steak", "text": ["1-1.jpg", "1-2.jpg", "1-3.jpg", "1-4.jpg", "1-5.jpg", "1-6.jpg", "10-1.jpg", "10-2.jpg", "10-3.jpg", "10-4.jpg", "10-5.jpg", "2-1.jpg", "3-1.jpg", "3-2.jpg", "3-3.jpg", "4-1.jpg", "4-2.jpg", "4-3.jpg", "4-4.jpg", "4-5.jpg", "5-1.jpg", "5-2.jpg", "5-3.jpg", "6-1.jpg", "6-2.jpg", "6-3.jpg", "6-4.jpg", "6-5.jpg", "6-6.jpg", "6-7.jpg", "7-1.jpg", "7-2.jpg", "7-3.jpg", "7-4.jpg", "7-5.jpg", "7-6.jpg", "8-1.jpg", "8-2.jpg", "8-3.jpg", "8-4.jpg", "8-5.jpg", "9-1.jpg", "9-2.jpg"], "mode": "markers", "y": [-5.3097381591796875, -5.848715305328369, -3.3656017780303955, -2.746361017227173, -5.078927040100098, -6.166965007781982, -6.097499370574951, -4.404089450836182, -4.149926662445068, -4.000457763671875, -5.827410697937012, -5.3332133293151855, -2.3830602169036865, -4.123445987701416, -2.7018072605133057, -4.554413318634033, -6.4752516746521, -4.340409755706787, -6.5779709815979, -2.943010091781616, -3.557774066925049, -6.815918445587158, -3.0912389755249023, -5.265024185180664, -3.5623440742492676, -4.918424606323242, -5.734227180480957, -5.835877895355225, -5.526300430297852, -5.657476425170898, -4.055576801300049, -6.788751125335693, -5.294569969177246, -2.7364554405212402, -5.0955891609191895, -4.183666706085205, -6.589054584503174, -5.090638637542725, -3.852168083190918, -5.057757377624512, -3.833446741104126, -4.574771404266357, -5.983379364013672], "x": [-2.9393532276153564, -0.10334524512290955, -1.6332870721817017, -0.46591052412986755, -0.7025671601295471, -3.8452422618865967, -2.2320964336395264, -2.684417963027954, -1.4383976459503174, -2.30196213722229, -2.087200880050659, -0.821201503276825, 0.004973577801138163, 0.45777076482772827, -0.8700891137123108, -2.1062557697296143, -4.003231525421143, -0.12474119663238525, 0.3698761761188507, -0.6365388631820679, -0.13508614897727966, -0.7219393253326416, -0.0017845839029178023, -2.195279121398926, -0.8730789422988892, -0.23402293026447296, -2.5330512523651123, -1.224777102470398, -1.1178783178329468, -0.8090027570724487, -0.4417780637741089, -3.5732932090759277, 0.41668933629989624, -0.6044672131538391, -1.8162822723388672, -1.537176251411438, -4.18890905380249, -3.9803032875061035, -2.810763359069824, -3.980203866958618, -2.6043787002563477, -3.321429967880249, -3.585117816925049]}, {"marker": {"line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7, "colorscale": "Viridis"}, "type": "scatter", "uid": "7f756590-72fd-407c-91ee-e7ccbf98dc6c", "name": "tiramisu", "text": ["1-1.jpg", "1-2.jpg", "1-3.jpg", "1-4.jpg", "10-1.jpg", "10-10.jpg", "10-2.jpg", "10-3.jpg", "10-4.jpg", "10-5.jpg", "10-6.jpg", "10-7.jpg", "10-8.jpg", "10-9.jpg", "2-1.jpg", "2-2.jpg", "2-3.jpg", "2-4.jpg", "2-5.jpg", "2-6.jpg", "2-7.jpg", "2-8.jpg", "2-9.jpg", "3-1.jpg", "3-2.jpg", "3-3.jpg", "3-4.jpg", "3-5.jpg", "3-6.jpg", "3-7.jpg", "3-8.jpg", "4-1.jpg", "4-2.jpg", "4-3.jpg", "4-4.jpg", "4-5.jpg", "4-6.jpg", "4-7.jpg", "4-8.jpg", "4-9.jpg", "5-1.jpg", "5-2.jpg", "5-3.jpg", "5-4.jpg", "6-1.jpg", "6-2.jpg", "6-3.jpg", "6-4.jpg", "7-1.jpg", "7-2.jpg", "7-3.jpg", "7-4.jpg", "7-5.jpg", "7-6.jpg", "7-7.jpg", "7-8.jpg", "8-1.jpg", "8-2.jpg", "8-3.jpg", "8-4.jpg", "8-5.jpg", "8-6.jpg", "8-7.jpg", "8-8.jpg", "9-1.jpg", "9-2.jpg", "9-3.jpg", "9-4.jpg", "9-5.jpg", "9-6.jpg", "9-7.jpg", "9-8.jpg", "9-9.jpg"], "mode": "markers", "y": [5.354975700378418, 1.7797644138336182, 4.702664375305176, -0.3265010416507721, 1.2879207134246826, -0.8061805963516235, -0.2519374191761017, 1.609863042831421, 2.164309024810791, 0.5706 ...

# %%
    #t-SNE 3D
    
    tsne_3D = TSNE(perplexity=20, n_components=3, verbose=2, init='pca',
                   n_iter=4000, n_iter_without_progress=1000, learning_rate=25, method='exact')
    low_dim_embs_3D = tsne_3D.fit_transform(features)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 160 / 160
# [t-SNE] Mean sigma: 4.227815
# [t-SNE] Iteration 50: error = 46.9289729, gradient norm = 0.2386396 (50 iterations in 0.194s)
# [t-SNE] Iteration 100: error = 46.1990084, gradient norm = 0.2102140 (50 iterations in 0.187s)
# [t-SNE] Iteration 150: error = 49.4483320, gradient norm = 0.1549029 (50 iterations in 0.190s)
# [t-SNE] Iteration 200: error = 50.7801520, gradient norm = 0.0870555 (50 iterations in 0.198s)
# [t-SNE] Iteration 250: error = 50.0884601, gradient norm = 0.1461012 (50 iterations in 0.194s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 50.088460
# [t-SNE] Iteration 300: error = 0.2577358, gradient norm = 0.0014393 (50 iterations in 0.194s)
# [t-SNE] Iteration 350: error = 0.2221788, gradient norm = 0.0003601 (50 iterations in 0.194s)
# [t-SNE] Iteration 400: error = 0.1939306, gradient norm = 0.0002698 (50 iterations in 0.189s)
# [t-SNE] Iteration 450: error = 0.1939599, gradient norm = 0.0000595 (50 iterations in 0.190s)
# [t-SNE] Iteration 500: error = 0.1939807, gradient norm = 0.0000271 (50 iterations in 0.181s)
# [t-SNE] Iteration 550: error = 0.1940593, gradient norm = 0.0000159 (50 iterations in 0.179s)
# [t-SNE] Iteration 600: error = 0.1941597, gradient norm = 0.0000123 (50 iterations in 0.192s)
# [t-SNE] Iteration 650: error = 0.1942563, gradient norm = 0.0000092 (50 iterations in 0.190s)
# [t-SNE] Iteration 700: error = 0.1943571, gradient norm = 0.0000065 (50 iterations in 0.192s)
# [t-SNE] Iteration 750: error = 0.1944381, gradient norm = 0.0000049 (50 iterations in 0.190s)
# [t-SNE] Iteration 800: error = 0.1944970, gradient norm = 0.0000037 (50 iterations in 0.189s)
# [t-SNE] Iteration 850: error = 0.1945426, gradient norm = 0.0000029 (50 iterations in 0.201s)
# [t-SNE] Iteration 900: error = 0.1945783, gradient norm = 0.0000022 (50 iterations in 0.191s)
# [t-SNE] Iteration 950: error = 0.1946047, gradient norm = 0.0000018 (50 iterations in 0.190s)
# [t-SNE] Iteration 1000: error = 0.1946224, gradient norm = 0.0000013 (50 iterations in 0.186s)
# [t-SNE] Iteration 1050: error = 0.1946384, gradient norm = 0.0000013 (50 iterations in 0.191s)
# [t-SNE] Iteration 1100: error = 0.1946494, gradient norm = 0.0000007 (50 iterations in 0.176s)
# [t-SNE] Iteration 1150: error = 0.1946591, gradient norm = 0.0000006 (50 iterations in 0.198s)
# [t-SNE] Iteration 1200: error = 0.1946659, gradient norm = 0.0000005 (50 iterations in 0.195s)
# [t-SNE] Iteration 1250: error = 0.1946709, gradient norm = 0.0000004 (50 iterations in 0.195s)
# [t-SNE] Iteration 1300: error = 0.1946752, gradient norm = 0.0000003 (50 iterations in 0.187s)
# [t-SNE] Iteration 1350: error = 0.1946784, gradient norm = 0.0000002 (50 iterations in 0.201s)
# [t-SNE] Iteration 1400: error = 0.1946806, gradient norm = 0.0000002 (50 iterations in 0.198s)
# [t-SNE] Iteration 1450: error = 0.1946824, gradient norm = 0.0000001 (50 iterations in 0.192s)
# [t-SNE] Iteration 1450: did not make any progress during the last 1000 episodes. Finished.
# [t-SNE] KL divergence after 1450 iterations: 0.194682

# %%
dict_TSNE_3D = {'pca-1' : low_dim_embs_3D[:,0],
     'pca-2' : low_dim_embs_3D[:,1],
     'pca-3' : low_dim_embs_3D[:,2],
     'labels' : labels,
     'colors' : color_indicies,
     'image_names': image_names}

df_3D=pd.DataFrame(dict_TSNE_3D)

# %%
traces=[]

for n in range(0,number_of_colors):
    df_category=df_3D[(df_3D.colors==n)]
    color=custom_color_map[n] if n < len(custom_color_map) else default_color
    point_name=str(df_category['labels'][df_category.index[0]])
    trace = go.Scatter3d(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    z=df_category['pca-3'],
    mode='markers',
    marker=dict(
        color=color,
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['image_names'],
    )

    traces.append(trace)


data = traces

layout = go.Layout(
    title='t-SNE reduction: 3D features',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
        zaxis = dict(
            title='pca-3',
        ),
    ),
 
)


fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div id="0f1bcc82-a317-440d-a26d-4dfc37dcc0b3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0f1bcc82-a317-440d-a26d-4dfc37dcc0b3", [{"uid": "18a44a17-8f2f-4e1a-902f-be0ed48da73f", "marker": {"opacity": 0.7, "color": "#9370DB", "line": {"color": "rgb(140, 140, 170)"}}, "text": ["1.jpg", "10-1.jpg", "10-2.jpg", "11-1.jpg", "11-2.jpg", "12-1.jpg", "12-2.jpg", "12-3.jpg", "13-1.jpg", "13-2.jpg", "14-1.jpg", "15.jpg", "2.jpg", "3.jpg", "4.jpg", "5.jpg", "6-1.jpg", "6-2.jpg", "6.jpg", "7-1.jpg", "7-2.jpg", "8-1.jpg", "8-2.jpg", "9-1.jpg", "9-2.jpg"], "type": "scatter3d", "mode": "markers", "y": [2.8778998851776123, 0.471498042345047, -0.7332877516746521, -0.4277111887931824, -0.523960292339325, 3.8065972328186035, 2.431913375854492, 2.1081950664520264, 0.27053818106651306, 0.1601063758134842, 2.801062822341919, 0.43138155341148376, 4.238386631011963, 3.4770538806915283, 3.21614146232605, 2.4900600910186768, 1.4543657302856445, 0.9683066010475159, 2.034834623336792, -0.0455000177025795, 0.8981118202209473, 3.0614607334136963, 0.5757328867912292, 4.945213317871094, 1.1832802295684814], "name": "sushi", "x": [8.897903442382812, 7.088902950286865, 1.7881428003311157, 2.5773613452911377, 2.6322059631347656, 8.679256439208984, 8.41446304321289, 7.8696184158325195, 7.316766738891602, 7.39672327041626, 9.101577758789062, 8.429388999938965, 9.596031188964844, 7.204238414764404, 9.923625946044922, 10.256023406982422, 7.61069393157959, 6.857831001281738, 7.486522197723389, 4.631672382354736, 8.508705139160156, 8.488879203796387, 6.170817852020264, 9.612284660339355, 7.01655912399292], "z": [-2.0019562244415283, -2.0799999237060547, -2.2122747898101807, -1.8828433752059937, -1.6462798118591309, -1.4409213066101074, -1.3604236841201782, -0.674993097782135, -0.7963384389877319, -0.6477705836296082, -1.021640419960022, -1.5285283327102661, -1.0080945491790771, -2.141498565673828, -1.4644694328308105, -1.564361333847046, -1.863635778427124, -1.8574460744857788, -2.2695984840393066, -2.3160176277160645, -2.2597522735595703, -0.7036907076835632, -1.5506864786148071, -0.8199125528335571, -1.4188343286514282]}, {"uid": "8a661987-cebe-45c0-97d4-d913073110c0", "marker": {"opacity": 0.7, "color": "#EE82EE", "line": {"color": "rgb(140, 140, 170)"}}, "text": ["1-1.jpg", "1-2.jpg", "1-3.jpg", "10-1.jpg", "2-1.jpg", "2-2.jpg", "2-3.jpg", "3-1.jpg", "3-2.jpg", "3-3.jpg", "4-1.jpg", "4-2.jpg", "4-3.jpg", "5-1.jpg", "6-1.jpg", "7-1.jpg", "8-1.jpg", "9-1.jpg", "9-2.jpg"], "type": "scatter3d", "mode": "markers", "y": [-2.752631187438965, -1.3988128900527954, -1.7115691900253296, 2.7829036712646484, 1.3001203536987305, -0.7042384147644043, 1.3245964050292969, 0.5015340447425842, -0.3208635747432709, 2.2755234241485596, -2.115966320037842, -0.9644755721092224, 0.01274232566356659, 1.7660644054412842, -1.341184139251709, 3.0963919162750244, 3.8598742485046387, 0.47122713923454285, 1.642896056175232], "name": "sashimi", "x": [1.418329119682312, 1.6639773845672607, 3.4632089138031006, 3.6999590396881104, 4.275496482849121, 2.5443663597106934, 4.363309383392334, 1.3872346878051758, 2.197481632232666, 3.2572097778320312, 1.9208780527114868, 1.9493917226791382, 0.8588795065879822, 3.70278263092041, 2.2329251766204834, 2.612543821334839, 6.173882484436035, 3.4121482372283936, 3.5097529888153076], "z": [-1.1345659494400024, -1.396768569946289, -1.6070259809494019, -1.7839395999908447, -0.09379251301288605, -0.4322497248649597, -0.3580254316329956, -0.45907720923423767, -2.9603500366210938, -0.7585558891296387, -0.9435286521911621, -1.3307982683181763, -2.1405117511749268, -0.9570135474205017, -3.3925678730010986, -1.448241114616394, -2.165708065032959, -2.011355400085449, -2.3161351680755615]}, {"uid": "62d848e0-7a2f-413d-b67a-b3b3e49e481a", "marker": {"opacity": 0.7, "color": "#6495ED ...

# %%
import os
import pandas as pd
import numpy as np
from tensorflow.python import pywrap_tensorflow
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

import plotly
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.plotly as py
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
def show_word_and_doc_embeddings():
    for tensor_name in var_to_shape_map:
        print("tensor_name: ", tensor_name) # get the variable name
        print(reader.get_tensor(tensor_name)) # get the variable
    
cwd=os.getcwd()
number_of_iteration=3
models_folder_name_train = os.path.join(cwd,'models','train',str(number_of_iteration))
models_folder_name_test = os.path.join(cwd,'models','test',str(number_of_iteration))
path_to_preprocessed_texts_train=os.path.join(models_folder_name_train,'recipes_train_dataset.pkl')
path_to_preprocessed_texts_test=os.path.join(models_folder_name_test,'recipes_test_dataset.pkl')
path_to_saved_model = os.path.join(models_folder_name_test,'doc2vec_recipes_checkpoint.ckpt')
path_to_save_docs_embeddings_pkl=os.path.join(models_folder_name_test,'docs_extracted_features.pkl')

reader = pywrap_tensorflow.NewCheckpointReader(path_to_saved_model)
var_to_shape_map = reader.get_variable_to_shape_map() # 'var_to_shape_map' is a dictionary contains every tensor in the model
#show_word_and_doc_embeddings()

docs_extracted_features_all = reader.get_tensor('doc_embeddings_all')
docs_extracted_features_all = docs_extracted_features_all.tolist() 
    
df_preprocessed_texts_train = pd.read_pickle(path_to_preprocessed_texts_train)
df_preprocessed_texts_test = pd.read_pickle(path_to_preprocessed_texts_test)
number_of_test_docs=df_preprocessed_texts_test.labels.count()
print(number_of_test_docs)
print(np.shape(docs_extracted_features_all))
df_preprocessed_texts_test
# Out:
# 9
# (45, 12)
#       labels  number_of_important_words  \
# 6    sashimi                         19
# 9    sashimi                         42
# 11     steak                         26
# 19     steak                         30
# 22     sushi                         96
# 24     sushi                        156
# 29     sushi                         53
# 39  tiramisu                         46
# 41  tiramisu                         23
#
#                                    preprocessed_texts text_names
# 6   [sushi, coriander, tuna, sashimi, piece, tuna,...      6.txt
# 9   [sushi, rice, rice, vinegar, vinegar, sugar, s...      9.txt
# 11  [onion, oil, vinegar, soy, sauce, pepper, stea...     10.txt
# 19  [butter, chive, pepper, salt, onion, powder, g...      9.txt
# 22  [sushi, salmon, raspberry, daikon, salmon, roe...     11.txt
# 24  [breast, sesame, oil, oil, sea, salt, teriyaki...     13.txt
# 29  [shrimp, tempura, sesame, seed, salt, oil, shr...      4.txt
# ...

# %%
path_to_docs_extracted_features_train=os.path.join(models_folder_name_train,'docs_extracted_features.pkl')
df_docs_extracted_features_train = pd.read_pickle(path_to_docs_extracted_features_train)
df_docs_extracted_features_train=df_docs_extracted_features_train.rename(columns={'features':'doc_embeddings'})
#df_docs_extracted_features_train
#print(docs_extracted_features_all)

docs_extracted_features_test = docs_extracted_features_all[-number_of_test_docs:]
print(np.shape(docs_extracted_features_test))
# Out:
# (9, 12)

# %%
 dict_docs_extracted_features_test = {
    'text_names': df_preprocessed_texts_test.text_names,
    'labels' : df_preprocessed_texts_test.labels,
    'doc_embeddings' : docs_extracted_features_test
}
    

df_docs_extracted_features_test=pd.DataFrame(dict_docs_extracted_features_test)
df_docs_extracted_features_test
# Out:
#                                        doc_embeddings    labels text_names
# 6   [0.7458409667015076, -0.15381520986557007, 2.6...   sashimi      6.txt
# 9   [1.1631393432617188, -1.1367578506469727, -0.4...   sashimi      9.txt
# 11  [0.08611156791448593, 0.575017511844635, 0.071...     steak     10.txt
# 19  [-0.5991517901420593, 1.9568560123443604, -0.6...     steak      9.txt
# 22  [-0.05625615641474724, 0.5053120851516724, -0....     sushi     11.txt
# 24  [0.22199919819831848, 0.16737902164459229, -0....     sushi     13.txt
# 29  [0.8976214528083801, -0.7309519052505493, -0.4...     sushi      4.txt
# 39  [-0.06464918702840805, 0.16021600365638733, -0...  tiramisu      4.txt
# 41  [1.6229568719863892, 1.2740808725357056, -0.60...  tiramisu      6.txt

# %%
df_docs_extracted_features_all=pd.concat([df_docs_extracted_features_train,df_docs_extracted_features_test])
df_docs_extracted_features_all=df_docs_extracted_features_all.sort_index()
df_doc_embeddings=df_docs_extracted_features_all
df_doc_embeddings
# Out:
#                                        doc_embeddings    labels text_names
# 0   [2.224745512008667, -0.801887571811676, -0.468...   sashimi      1.txt
# 1   [-0.9511348605155945, 0.17868880927562714, 4.0...   sashimi     10.txt
# 2   [-0.4876479506492615, 2.4967477321624756, 3.45...   sashimi      2.txt
# 3   [0.763983428478241, 0.8407589197158813, 2.8933...   sashimi      3.txt
# 4   [0.560888409614563, 0.212759867310524, 2.55800...   sashimi      4.txt
# 5   [0.6497139930725098, 1.8405461311340332, 0.483...   sashimi      5.txt
# 6   [0.7458409667015076, -0.15381520986557007, 2.6...   sashimi      6.txt
# 7   [2.4125256538391113, 1.6674818992614746, 0.597...   sashimi      7.txt
# 8   [-2.2634096145629883, -2.6045920848846436, 1.4...   sashimi      8.txt
# 9   [1.1631393432617188, -1.1367578506469727, -0.4...   sashimi      9.txt
# 10  [-1.284438133239746, 0.3390555679798126, -0.48...     steak      1.txt
# ...

# %%
doc_embeddings=df_doc_embeddings.doc_embeddings.values.tolist()
labels=df_doc_embeddings.labels.values.tolist()
text_names=df_doc_embeddings.text_names.values.tolist()

unique_labels=sorted(set(labels))
number_of_recipe_categories=len(unique_labels)
possible_category_indices=np.linspace(0,number_of_recipe_categories-1,number_of_recipe_categories,dtype=int)
labels2integers=dict(zip(unique_labels,possible_category_indices))

print(labels2integers)

category_indices=[]
for l in labels:
    category_index=labels2integers[l]
    category_indices.append(category_index)
# Out:
# {'steak': 1, 'sushi': 2, 'sashimi': 0, 'tiramisu': 3}

# %%
#PCA

pca = PCA(n_components=2)
pca_2D_embeddings = pca.fit_transform(doc_embeddings)

dict_PCA_2D = {
    'pca-1' : pca_2D_embeddings[:,0],
    'pca-2' : pca_2D_embeddings[:,1],
    'labels' : labels,
    'category_indices': category_indices,
    'text_names': text_names
}

df_PCA_2D=pd.DataFrame(dict_PCA_2D)

# %%
traces=[]

for n in range(0,number_of_recipe_categories):
    df_category=df_PCA_2D[(df_PCA_2D.category_indices==n)]
    point_name=str(df_category.labels[df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['text_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='PCA reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)


print("test recipes")
df_preprocessed_texts_test
# Out:
# <div id="603a2f17-9b70-43a2-bff0-db4e707b2670" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("603a2f17-9b70-43a2-bff0-db4e707b2670", [{"name": "sashimi", "uid": "eb7761f6-27c2-4ee4-87a8-59537a247bb3", "type": "scatter", "mode": "markers", "x": [1.6911910296309924, 0.6463409525797513, 0.9611417802645056, 1.461079480793458, 3.335598920191035, 0.8043653690607852, 1.4798404211606033, 1.686586145884945, 2.2738286803395376, 1.2641219066677074], "y": [-0.12197293392287693, 1.0715365106780044, 0.21918405418863002, -1.3489791462289018, 0.291007778841104, -0.22354634827522957, -1.0181502259633868, 0.9915342839072971, 0.33556676353138787, 0.5761507873224685], "marker": {"colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7}, "text": ["1.txt", "10.txt", "2.txt", "3.txt", "4.txt", "5
# ...

# %%
#t-SNE 2D
    
tsne2D = TSNE(perplexity=35, n_components=2, verbose=2, init='pca', n_iter=2000,
                  n_iter_without_progress=500, learning_rate=5,method='exact')
tsne_2D_embeddings = tsne2D.fit_transform(doc_embeddings)
    
dict_TSNE_2D = {
    'pca-1' : tsne_2D_embeddings[:,0],
    'pca-2' : tsne_2D_embeddings[:,1],
    'labels' : labels,
    'category_indices': category_indices,
    'text_names': text_names
}

df_TSNE_2D=pd.DataFrame(dict_TSNE_2D)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 45 / 45
# [t-SNE] Mean sigma: 4.593882
# [t-SNE] Iteration 50: error = 32.1682703, gradient norm = 0.0039937 (50 iterations in 0.098s)
# [t-SNE] Iteration 100: error = 32.1682697, gradient norm = 0.0000032 (50 iterations in 0.052s)
# [t-SNE] Iteration 150: error = 32.1682697, gradient norm = 0.0000001 (50 iterations in 0.047s)
# [t-SNE] Iteration 150: gradient norm 0.000000. Finished.
# [t-SNE] KL divergence after 150 iterations with early exaggeration: 32.168270
# [t-SNE] Iteration 200: error = 0.1250701, gradient norm = 0.0101560 (50 iterations in 0.040s)
# [t-SNE] Iteration 250: error = 0.0751677, gradient norm = 0.0007419 (50 iterations in 0.032s)
# [t-SNE] Iteration 300: error = 0.0751337, gradient norm = 0.0000140 (50 iterations in 0.033s)
# [t-SNE] Iteration 350: error = 0.0751337, gradient norm = 0.0000002 (50 iterations in 0.031s)
# ...

# %%
traces=[]

for n in range(0,number_of_recipe_categories):
    df_category=df_TSNE_2D[(df_TSNE_2D.category_indices==n)]
    point_name=str(df_category.labels[df_category.index[0]])
    trace = go.Scatter(
    x=df_category['pca-1'],
    y=df_category['pca-2'],
    mode='markers',
    marker=dict(
        colorscale='Viridis',
        opacity=0.7,
        line=dict(color='rgb(140, 140, 170)')
    ),
    name=point_name,
    text=df_category['text_names'],
    )

    traces.append(trace)

layout = go.Layout(
    title='t-SNE reduction: 2D features',
    hovermode='closest',
    margin=dict(
       l=30,
       r=30,
       b=30,
       t=30
    ),
      scene = dict(
        xaxis = dict(
            title='pca-1',
       ),
       yaxis = dict(
           title='pca-2',
       ),
    ),
 
)

fig = go.Figure(data=traces, layout=layout)
iplot(fig)

print("test recipes")
df_preprocessed_texts_test
# Out:
# <div id="ae27e499-ae61-4d72-86c2-424dfa999c9a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ae27e499-ae61-4d72-86c2-424dfa999c9a", [{"name": "sashimi", "uid": "6c0a885b-0bb5-4b0a-ac90-0e8ad8b21509", "type": "scatter", "mode": "markers", "x": [-0.0847584679722786, -0.8914088010787964, -0.8804717063903809, -0.6130738854408264, -0.15320508182048798, -0.6065778136253357, -0.48919546604156494, -0.6552895307540894, -0.09553957730531693, 0.11447000503540039], "y": [0.7385844588279724, 1.2441942691802979, 0.8678973913192749, 0.8351790308952332, 1.4326835870742798, 0.5792441964149475, 0.8250036239624023, 1.2386277914047241, 1.2146542072296143, 0.42388200759887695], "marker": {"colorscale": "Viridis", "line": {"color": "rgb(140, 140, 170)"}, "opacity": 0.7}, "text": ["1.txt", "10.txt", "2.txt", "3.txt", "
# ...

# %%
print("Saving extracted features from test dataset pandas dataframe to: ", path_to_save_docs_embeddings_pkl)
df_docs_extracted_features_test.to_pickle(path_to_save_docs_embeddings_pkl)

#print("Extracted features from test dataset pandas dataframe:")
#df_docs_extracted_features_test


path_to_save_train_test_docs_extracted_features=os.path.join(cwd,os.pardir,'multimodal_classification','data','docs_extracted_features.pkl')
print("Saving extracted features from train and from test dataset pandas dataframe to: ", path_to_save_train_test_docs_extracted_features)
df_doc_embeddings.to_pickle(path_to_save_train_test_docs_extracted_features)

print("Extracted features from train and from test dataset pandas dataframe:")
df_doc_embeddings
# Out:
# Saving extracted features from test dataset pandas dataframe to:  /notebooks/school/text_feature_extraction/models/test/3/docs_extracted_features.pkl
# Saving extracted features from train and from test dataset pandas dataframe to:  /notebooks/school/text_feature_extraction/../multimodal_classification/data/docs_extracted_features.pkl
# Extracted features from train and from test dataset pandas dataframe:
#                                        doc_embeddings    labels text_names
# 0   [2.224745512008667, -0.801887571811676, -0.468...   sashimi      1.txt
# 1   [-0.9511348605155945, 0.17868880927562714, 4.0...   sashimi     10.txt
# 2   [-0.4876479506492615, 2.4967477321624756, 3.45...   sashimi      2.txt
# 3   [0.763983428478241, 0.8407589197158813, 2.8933...   sashimi      3.txt
# 4   [0.560888409614563, 0.212759867310524, 2.55800...   sashimi      4.txt
# 5   [0.6497139930725098, 1.8405461311340332, 0.483...   sashimi      5.txt
# ...
